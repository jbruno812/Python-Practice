# %% [markdown]
# # Basic Web Scraping Using Beautiful Soup
#
# This is a multi-part webscraping Python assignment. Please follow each segment of directions.
#
# As always, your code should be reasonably efficient, utilize docstrings where necessary, and use appropriate error-handling.

# %%
import requests
from bs4 import BeautifulSoup as soup
import bs4
import pandas as pd

# %% [markdown]
# ## Web site to scrape
# Below is the URL from which you will scrape the name, title and phone number for each faculty member at Lamar School.

# %%
url = "http://www.lamarschool.com/about-us/faculty.cfm"

# %% [markdown]
# ## Initialize headers and get the HTML page

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}

r = requests.get(url, headers=headers)

print(str(r.content)[:1000])
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n<meta charset="utf-8">\r\n<meta name="viewport" content="width=device-width,user-scalable=no,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0">\r\n<meta name="keywords" content="Lamar School,independant,East Mississippi,West Alabama,Christian,MPSA,SACS,CASI,Meridian,MS,Mississippi,39305" />\r\n<meta name="robots" content="index,follow" />\r\n<meta http-equiv="cache-control" content="max-age=172800" />\r\n\r\n<title>Faculty - Lamar School</title>\r\n\r\n<link rel="shortcut icon" href="/custom/images/favicon.ico" />\r\n\r\n<link href="http://www.lamarschool.com/pro/responsive/css/global.css?v=09272019150000" rel="stylesheet" type="text/css" />  \r\n\r\n\r\n\r\n<link href="http://www.lamarschool.com/css.css?v=05032020000500" rel="stylesheet" type="text/css" />\r\n\r\n\r\n\t<link href="http://www.lamarschool.com/implementation_colors.css?v=05032020000500" rel="stylesheet" type="text/css"  />\r\n\r\n\r\n\r\n<link href="http://www.lamar

# %% [markdown]
# ## Parse the HTML

# %%
# Use Beautiful Soup to parse the HTML. 
# Pass the HTML page (.content returns bytes, .text returns string) and use the "html.parser"
soup = bs4.BeautifulSoup(r.content, 'html.parser')

# Optional: print the soup object you created above

# %%
# Print the title of the web site to verify you have successfully parsed the page
soup.title
# Out:
# <title>Faculty - Lamar School</title>

# %% [markdown]
# ## Scrape name, title and phone number
# Now that you have successfully retrieved the HTML for the faculty page, next we want to scrape the faculty name, title, and number.
#
# Once you have scraped the data return and print a formatted list of the facutly names, titles phone numbers similar the example below:
#
# ```
# Adams, Shane
#   Title:  Dir of Athletics and  Facilities
#   Phone:  601-482-1345
#
# Alexander, Danny
#   Title:  HS Science
#   Phone:  601-482-1345
#
# Autry, Bill
#   Title:  Tennis Coach
#   Phone:  601-482-1345
# ```
#
# Do this in an assignment named **info_scraping()** that returns the formatted list. Remember to print the formatted list as well.

# %%
# Scrape faculty name, title, and phone number

def info_scraping():
    """ This function takes the name, title, and phones of the faculty at the url:http://www.lamarschool.com/about-us/faculty.cfm
         then formats and displays them""" 
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.content)
    faculty_data = soup.find_all('tr',{'class':'directory-row dir-row dir-border'})

    for i,f in enumerate(faculty_data,1):
        try:
            names = f.find('td', attrs = {'class':'dir-name'}).text.strip()
            titles = f.find('td', attrs = {'class':'dir-col2'}).text.strip()
            phones = f.find('td', attrs = {'class':'dir-col4'}).text.strip()
            faculty_final = "{}\n " " " " Title: " " " " {}\n " " " " Contact: {} \n".format(names, titles, phones)
            print(faculty_final)
        except NameError as e:
            print(e)
        except Exception as e:
            print(e)

# %%
# Print formatted listing of faculty name, title, phone
info_scraping()
# Out:
# Adams, Shane
#    Title:   Dir of Athletics and  Facilities
#    Contact: 601-482-1345
#
# Bakane, Heather
#    Title:   MS English
#    Contact: 601-482-1345
#
# Ballou, Leigh Ann
#    Title:   Head of School
#    Contact: 601-482-1345
#
# Barnes, Mac
#    Title:   Bible, Head Football Coach
#    Contact: 601-482-1345
#
# Brown, Ashley
#    Title:   HS Spanish Teacher
#    Contact: 6014821345
#
# Brown, Stephanie
#    Title:   Dual Credit Biology
#    Contact: 601-484-8664
#
# Browne, Marilyn
#    Title:   MS/HS  Math
#    Contact: 601-482-1345
#
# Cade, Burt
#    Title:   HS Math
#    Contact: 601-482-1345
#
# Carruth, Leslie
#    Title:   MS/HS Art
#    Contact: 601-482-1345
#
# Carver, Andrea
#    Title:   Discovery
#    Contact: 601-482-1345
#
# Castle, Jamie
#    Title:
#    Contact:
#
# Chesney, Miriam
#    Title:   Elem. Music
#    Contact: 601-482-1345
#
# Clodfelter, April
#    Title:   Pre-Kindergarten
#    Contact: 601-482-1345
#
# Cole, Beth
#    Title:   Elem. Admissions & Academics
#    Contact: 601-482-1345
#
# Cook, Angie
#    Title:   High School Secretary
#    Contact: 601-693-8111
#
# Cook, Toni
#    Title:
#    Contact: 601-482-1345
#
# Covington, Diana
#    Title:   MS  Math
#    Contact: 601-482-1345
#
# Dale, Michael
#    Title:   HS History
#    Contact: 601-482-1345
#
# Daniels, Brett
#    Title:   HS US History
#    Contact: 601-482-1345
#
# Davis, Bethany
#    Title:   HS Physics/Dual Credit Phys. Science
#    Contact: 601-482-1345
#
# Dearman, Yolanda
#    Title:   Elementary Spanish
#    Contact: 601-482-1345
#
# DeBardeleben, Mary Katherine
#    Title:   Alumni Relations, Admin. Asst.
#    Contact: 601-482-1345
#
# DeVuono, Kimberly
#    Title:   Pre-Kindergarten Assistant
#    Contact: 601-482-1345
#
# Diaz, Cesar
#    Title:   Boys Soccer Coach
#    Contact:
#
# Dulaney, Linda
#    Title:   Middle School Principal
#    Contact: 601-482-1345
#
# Dye, Gena
#    Title:   HS English, Librarian
#    Contact: 601-482-1345
#
# Ford, Kathryn
#    Title:   2nd Grade
#    Contact: 601-482-1345
#
# Gavin, Jill
#    Title:   Elementary Secretary
#    Contact: 601-482-1345
#
# Gordy, Becky
#    Title:   Kindergarten Assistant
#    Contact: 601-482-1345
#
# Grimes, Joan
#    Title:   HS English
#    Contact: 601-482-1345
#
# Guebara, Adrian
#    Title:   Assit Baseball & Football Coach
#    Contact: 601-482-1345
#
# Hendricks, Shirley
#    Title:   MS Computer Apps & AP Gov't
#    Contact: 601-482-1345
#
# Henson, Ralph
#    Title:   HS World History
#    Contact: 601-482-1345
#
# Hines, Candice
#    Title:   2nd Grade
#    Contact: 601-482-1345
#
# Honeycutt, Elizabeth
#    Title:   1st Grade
#    Contact: 601-693-8111
#
# Honeycutt, Erin
#    Title:   Elementary Principal
#    Contact: 601-482-1345
#
# Jones, Mary
#    Title:   HS Math
#    Contact: 601-482-1345
#
# Litchfield, Beverly
#    Title:   3rd Grade
#    Contact: 601-482-1345
#
# Long, Enley
#    Title:   Kindergarten
#    Contact: 601-482-1345
#
# Mabry, Anna
#    Title:   MS Science
#    Contact: 601-482-1345
#
# Mabry, Melissa
#    Title:   Dir of Finance
#    Contact: 601-482-1345
#
# Madden, Bobby
#    Title:   MS History
#    Contact: 601-482-1345
#
# Madden, Darlene
#    Title:   MS English
#    Contact: 601-482-1345
#
# Matlock, Belinda
#    Title:   MS Science
#    Contact: 601-482-1345
#
# McCormick, Dawn
#    Title:   MS History
#    Contact: 601-482-1345
#
# McElroy, Dana
#    Title:   1st Grade Assistant
#    Contact: 601-482-1345
#
# Mendoza, Stephanie
#    Title:
#    Contact:
#
# Miller, Joe
#    Title:   Head Girls Basketball Coach
#    Contact: 601-482-1345
#
# Mims, Anna
#    Title:   2nd Grade
#    Contact: 601-482-1345
#
# Mitchell, Tracy
#    Title:   PK Teacher
#    Contact: 601-482-1345
#
# Nelson, Steven
#    Title:   High School Principal
#    Contact: 601-482-1345
#
# Palmer, Emily
#    Title:   3rd Grade
#    Contact: 601-482-1345
#
# Pasha, Michelle
#    Title:   Performing Arts & MS Music
#    Contact: 601-482-1345
#
# Pevey, Leslie
#    Title:   HS English II
#    Contact: 601-482-1345
#
# Pollman, Mia
#    Title:   Asst. to Head/Technology Coordinator
#    Contact: 601-482-1345
#
# Pollman, Ree
#    Title:   Kindergarten
#    Contact: 601-482-1345
#
# Quigley, Julie
#    Title:   1st Grade Assistant
#    Contact: 601-482-1345
#
# Ransier, Jamie
#    Title:   HS English III
#    Contact: 601-482-1345
#
# Rector, Colleen
#    Title:   5th Grade
#    Contact: 601-482-1345
#
# Rector, Colleen
#    Title:   TeacherM
#    Contact: 601-482-1345
#
# Rhett, Beth
#    Title:   MS English
#    Contact: 601-482-1345
#
# Roman, Stefanie
#    Title:   MS Secretary
#    Contact: 601-482-1345
#
# Salas Jensen, Rocio
#    Title:   HS Spanish II
#    Contact: 601-482-1345
#
# Schimelpfening, Courtney
#    Title:   Volleyball Coach
#    Contact:
#
# Shaffer, Charles
#    Title:   MS Science
#    Contact: 601-482-1345
#
# Shedd, Danielle
#    Title:   4th Grade Teacher
#    Contact: 601-482-1345
#
# Singley, Stephanie
#    Title:   Elementary Stem Lab
#    Contact: 601-482-1345
#
# Skipper, Phyllis
#    Title:   Geometry, Pre-Calculus, Calculus
#    Contact: 601-482-1345
#
# Skotko, Natalie
#    Title:   Kindergarten Assistant
#    Contact: 601-482-1345
#
# Slay, Amanda
#    Title:   Biology I and II
#    Contact:
#
# Smith, Susan
#    Title:   4th Grade Teacher
#    Contact: 601-482-1345
#
# Sterling, Nancy
#    Title:   Elementary  PE
#    Contact: 601-482-1345
#
# Syner, Sandy
#    Title:   Elementary Librarian
#    Contact: 601-482-1345
#
# Tate, Leigha
#    Title:   MS Math
#    Contact: 601-482-1345
#
# Temple, Amy
#    Title:   2nd Grade
#    Contact: 601-482-1345
#
# Triplett, Holly
#    Title:   Elementary Art
#    Contact: 601-482-1345
#
# Vollor, Will
#    Title:   Government, Economics, Criminal Law, Health
#    Contact: 601-482-1345
#
# Warden, Megan
#    Title:   K Assistant
#    Contact: 601-482-1345
#
# Westbrook, Rachel
#    Title:   MS/HS Counselor
#    Contact: 601-482-1345
#
# Westbrook, Robert
#    Title:   Anatomy & Physiology
#    Contact: 601-482-1345
#
# Whittington, Shelley
#    Title:   Kindergarten Teacher
#    Contact: 601-482-1345
#
# Young, Anna
#    Title:   1st Grade Teacher
#    Contact: 601-482-1345
